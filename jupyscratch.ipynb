# %%
print("I love jupyter")
# Out:
# I love jupyter

# %%
# This is a comment

def addition(number_one, number_two):
    sum = number_one + number_two
    print(f"Ths sum is {sum}!")
    return sum
    two_num = addition(3,4)
# value_added=addition(2,3)
print(f"I added two numbers together and the sum is {two_num}!")
# Out:
# Ths sum is 5!
# I added two numbers together and the sum is 5!
